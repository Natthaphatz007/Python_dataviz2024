# %% [markdown]
# <a href="https://colab.research.google.com/github/Natthaphatz007/Python_dataviz2024/blob/main/Visualize_Data_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# สอน 1 เมษา 2564

# %%
import pandas as pd
import os
from datetime import datetime as dt
from datetime import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/data_viz_2024/Movies.csv'

# %%
data = pd.read_csv(os.path.join(path,'barchart_data.csv'))
data = data.iloc[:,1:]
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e1e2dc30ffe4> in <cell line: 1>()
# ----> 1 data = pd.read_csv(os.path.join(path,'barchart_data.csv'))
#       2 data = data.iloc[:,1:]
#       3 data.head()
#
# ...

# %%
# prompt: การใช้ DataFrame data: replace Word Budget in the Price Category with รุ่นเริ่มต้น

# Replace "Budget" with "รุ่มเริ่มต้น" in the "Price Category" column.
data['Price Category'] = data['Price Category'].replace('Budget', 'รุ่นประหยัด')
data['Price Category'] = data['Price Category'].replace('Mid-range', 'รุ่นเริ่มต้น')
data['Price Category'] = data['Price Category'].replace('Premium', 'รุ่นเรือธง')

# %%
data
# Out:
#      Year Quarter         Region   Brand Price Category  Sales
# 0    2021      Q1  North America  BrandA    รุ่นประหยัด   8270
# 1    2021      Q1  North America  BrandA   รุ่นเริ่มต้น   1860
# 2    2021      Q1  North America  BrandA     รุ่นเรือธง   6390
# 3    2021      Q1  North America  BrandB    รุ่นประหยัด   6191
# 4    2021      Q1  North America  BrandB   รุ่นเริ่มต้น   6734
# ..    ...     ...            ...     ...            ...    ...
# 475  2022      Q4         Africa  BrandC   รุ่นเริ่มต้น   6486
# 476  2022      Q4         Africa  BrandC     รุ่นเรือธง   9335
# 477  2022      Q4         Africa  BrandD    รุ่นประหยัด   5980
# 478  2022      Q4         Africa  BrandD   รุ่นเริ่มต้น   8266
# 479  2022      Q4         Africa  BrandD     รุ่นเรือธง   5491
#
# [480 rows x 6 columns]

# %% [markdown]
# ## Bar chart (กราฟแท่ง)
# (กราฟผลไม้)

# %%
# prompt: การใช้ DataFrame data: สร้าง bar chart เปรียบเทียบปริมาณ sales ทั้งหมดของแต่ละ region

import matplotlib.pyplot  as plt

# Group data
region_sales = data.groupby('Region')['Sales'].sum()

# Create a bar chart
plt.bar(region_sales.index, region_sales.values)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region')

# Show the chart
plt.show()

# %%
region_sales.reset_index()['Region']
# Out:
# 0           Africa
# 1             Asia
# 2           Europe
# 3    North America
# 4    South America
# Name: Region, dtype: object

# %%
region_sales.reset_index().Region
# Out:
# 0           Africa
# 1             Asia
# 2           Europe
# 3    North America
# 4    South America
# Name: Region, dtype: object

# %%
# Group data
region_q_sales = data.groupby(['Region','Quarter'])['Sales'].sum()
region_q_sales
# Out:
# Region         Quarter
# Africa         Q1         124543
#                Q2         144451
#                Q3         141602
#                Q4         130960
# Asia           Q1         123201
#                Q2         140369
#                Q3         125413
#                Q4         130625
# Europe         Q1         136996
#                Q2         139328
#                Q3         141905
#                Q4         129839
# North America  Q1         130631
#                Q2         144435
#                Q3         124104
#                Q4         146393
# South America  Q1         127485
#                Q2         138468
#                Q3         132925
#                Q4         130368
# Name: Sales, dtype: int64

# %%
from pickle import TRUE
import matplotlib.pyplot as plt #Removed unintended indent

region_pice = data.groupby(['Region', 'Quarter'])['Sales'].sum().unstack()
#สร้างกราฟแท่ง
region_pice.plot(kind='bar', stacked=True)


plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region')
plt.show()

# %% [markdown]
# ## plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

# %%
from pickle import TRUE
import matplotlib.pyplot as plt #Removed unintended indent

region_pice = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()
#สร้างกราฟแท่ง
region_pice.plot(kind='bar', stacked=True)


plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region')
plt.show()

# %% [markdown]
# ### สร้างกราฟแท่งเปรียบเทียบปริมาณ คนเข้าใช้ web Wongnai.com เพื่อค้นหาร้านอาหาร ในแต่ละวัน
#
# quiz 6

# %%
data[data['search_timestamp'].dt.dayofweek == 0].shape[0]
# Out:
# 1076297

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ส่วนประกอบของกราฟแท่ง
#
#
# *   ตัวกราฟแท่ง (height)
# *   ตำแหน่งกราฟแท่ง (x)
# *   ชื่อแท่ง (tick_label)
# *   ชื่อกราฟ (plt.title)
# *   ชื่อแกน x (plt.xlabel)
# *   ชื่อแกน y (plt.ylabel)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %% [markdown]
# การแสดงตัวอักษรภาษาไทยในกราฟ matplotlib
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31
#
#
# https://colab.research.google.com/drive/1sTdTZx_Cm51mc8OL_QHtehWyO4725sGl#scrollTo=Ak9SbVd5L7U8

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
plt.title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน');

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
# Out:
# Text(0, 0.5, 'Number of Requests')

# %%
from pickle import TRUE
import matplotlib.pyplot as plt #Removed unintended indent

region_pice = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()
#สร้างกราฟแท่ง
region_pice.plot(kind='bar', stacked=True)


plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region')
plt.show()

# %% [markdown]
# ## Plot stacked barchart ด้วย matplotlib

# %%
region_brand_sales = data.groupby(['Region','Brand'])['Sales'].sum().unstack()
region_brand_sales
# Out:
# Brand          BrandA  BrandB  BrandC  BrandD
# Region
# Africa         132019  140187  132273  137077
# Asia           136205  124678  139677  119048
# Europe         135638  135069  131700  145661
# North America  124810  153135  140802  126816
# South America  144169  138543  115774  130760

# %% [markdown]
# ## plot ส่วนแรก

# %%
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax.bar(region_brand_sales.index , region_brand_sales['BrandA'].values , width , label='BrandA',color = '#fc9700')
#ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Sales')
ax.set_xlabel('Region')
ax.set_title('Total Sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่สอง

# %%
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax.bar(region_brand_sales.index , region_brand_sales['BrandA'].values , width , label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index , region_brand_sales['BrandB'].values , width , bottom=region_brand_sales['BrandA'].values , label='BrandB',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Sales')
ax.set_xlabel('Region')
ax.set_title('Total Sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่สาม

# %%
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax.bar(region_brand_sales.index , region_brand_sales['BrandA'].values , width , label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index , region_brand_sales['BrandB'].values , width , bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
ax.bar(region_brand_sales.index , region_brand_sales['BrandC'].values , width , bottom=region_brand_sales['BrandA'].values+region_brand_sales['BrandB'].values, label='BrandC',color = '#ff5733')
ax.bar(region_brand_sales.index , region_brand_sales['BrandD'].values , width , bottom=region_brand_sales['BrandA'].values+region_brand_sales['BrandB'].values+region_brand_sales['BrandC'], label='BrandD',color = '#b50713')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Sales')
ax.set_xlabel('Region')
ax.set_title('Total Sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## Grouped bar chart (Compare in group)

# %%
# prompt: plot grouped bar chart ของแต่ละ region ในปี 2021 เพื่อเปรียบเทียบ sales ของแต่ละ price category ย้าย legend ออกไปข้างนอกกราฟ ปรับขนาด plot ให้เล็กลง 30%

# Group data
region_price_sales_2021 = data[data['Year'] == 2021].groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create grouped bar chart
ax = region_price_sales_2021.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region and Price Category in 2021')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the chart
plt.show()

# %% [markdown]
# ## Plot Grouped bar chart ของ หนังอินเดีย โดย แยกกลุ่มประเภทหนังและเปรียบเทียบ rating จาก ความยาวของหนัง(Duration)

# %%
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/data_viz_2024_DATA/'

# %%
india_file_path = os.path.join(path,'IMDb Movies India.csv')
print(india_file_path)
# Out:
# /content/drive/My Drive/data_viz_2024_DATA/IMDb Movies India.csv

# %%
data_india = pd.read_csv(india_file_path, encoding='latin-1') # Try reading the file with 'latin-1' encoding
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data_india = data_india.dropna(subset=['Year','Duration','Votes'])
data_india = data_india[['Year','Duration','Votes']] # Use square brackets to select columns
data_india
# Out:
#          Year Duration  Votes
# 1      (2019)  109 min      8
# 3      (2019)  110 min     35
# 5      (1997)  147 min    827
# 6      (2005)  142 min  1,086
# 8      (2012)   82 min    326
# ...       ...      ...    ...
# 15493  (2015)  115 min    408
# 15494  (2001)  153 min  1,496
# 15503  (1989)  125 min     44
# 15505  (1999)  129 min    655
# 15508  (1998)  130 min     20
#
# [5851 rows x 3 columns]

# %%
data_india
# Out:
#          Year Duration  Votes
# 1      (2019)  109 min      8
# 3      (2019)  110 min     35
# 5      (1997)  147 min    827
# 6      (2005)  142 min  1,086
# 8      (2012)   82 min    326
# ...       ...      ...    ...
# 15493  (2015)  115 min    408
# 15494  (2001)  153 min  1,496
# 15503  (1989)  125 min     44
# 15505  (1999)  129 min    655
# 15508  (1998)  130 min     20
#
# [5851 rows x 3 columns]

# %%
# prompt: เปลี่ยน year ตัด () ออก

# Remove parentheses from the "Year" column
data_india['Year'] = data_india['Year'].str.strip("()").astype(int)

# %%
data_india
# Out:
#        Year Duration  Votes
# 1      2019  109 min      8
# 3      2019  110 min     35
# 5      1997  147 min    827
# 6      2005  142 min  1,086
# 8      2012   82 min    326
# ...     ...      ...    ...
# 15493  2015  115 min    408
# 15494  2001  153 min  1,496
# 15503  1989  125 min     44
# 15505  1999  129 min    655
# 15508  1998  130 min     20
#
# [5851 rows x 3 columns]

# %%
# Remove " min" from the Duration column
data_india['Duration'] = data_india['Duration'].str.replace(' min', '')

# Convert the Duration column to integer
data_india['Duration'] = data_india['Duration'].astype(int)

# %%
data_india
# Out:
#        Year  Duration  Votes
# 1      2019       109      8
# 3      2019       110     35
# 5      1997       147    827
# 6      2005       142  1,086
# 8      2012        82    326
# ...     ...       ...    ...
# 15493  2015       115    408
# 15494  2001       153  1,496
# 15503  1989       125     44
# 15505  1999       129    655
# 15508  1998       130     20
#
# [5851 rows x 3 columns]

# %%
# prompt: เลิกหนังที่มีโหวต 1000 ขึ้นไป
# Remove commas from the 'Votes' column and convert to integer
data_india['Votes'] = data_india['Votes'].str.replace(',', '').astype(int)

# %%
data_india = data_india[data_india['Votes'] >= 1000]

# %%
data_india
# Out:
#        Year  Duration  Votes
# 6      2005       142   1086
# 15     2018       102   6619
# 28     2009       146   6329
# 30     2005       116   1002
# 33     2002       158   1235
# ...     ...       ...    ...
# 15437  1997       170   1551
# 15440  2013       142   1301
# 15447  2006       116   3314
# 15476  2011       155  70344
# 15494  2001       153   1496
#
# [1369 rows x 3 columns]

# %%
# prompt: แบ่งเป็นทศววศ สร้างคอลัมภ์ใหม่ 80s 90s 2000

# Function to categorize the year into decades
def categorize_decade(year):
  if 1980 <= year <= 1989:
    return '80s'
  elif 1990 <= year <= 1999:
    return '90s'
  elif 2000 <= year <= 2009:
    return '2000s'

# Apply the function to create the new column
data_india['Decade'] = data_india['Year'].apply(categorize_decade)
# Out:
# <ipython-input-47-577b823850f8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_india['Decade'] = data_india['Year'].apply(categorize_decade)

# %%
data_india
# Out:
#        Year  Duration  Votes Decade
# 6      2005       142   1086  2000s
# 15     2018       102   6619   None
# 28     2009       146   6329  2000s
# 30     2005       116   1002  2000s
# 33     2002       158   1235  2000s
# ...     ...       ...    ...    ...
# 15437  1997       170   1551    90s
# 15440  2013       142   1301   None
# 15447  2006       116   3314  2000s
# 15476  2011       155  70344   None
# 15494  2001       153   1496  2000s
#
# [1369 rows x 4 columns]

# %%
# prompt: สร้าง column ใหม่ แยกduration ออกเป็น short middle long

# Function to categorize duration
def categorize_duration(duration):
  if duration <= 90:
    return 'short'
  elif 90 < duration <= 150:
    return 'middle'
  elif duration > 150:
    return 'long'

# Apply the function to create the new column
data_india['Duration_Category'] = data_india['Duration'].apply(categorize_duration)
# Out:
# <ipython-input-59-0b99ec133925>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_india['Duration_Category'] = data_india['Duration'].apply(categorize_duration)

# %%
# prompt:   plot bar chart ของ ข้อมูล duration กับ dacade แล้ว plot กราฟ เส้น ของ votes ใส่ด้วยกัน แยกสีของกราฟเส้นคนละสี

# Group data
duration_decade_votes = data_india.groupby(['Decade', 'Duration_Category'])['Votes'].mean().unstack()

# Create bar chart
ax = duration_decade_votes.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Decade')
plt.ylabel('Average Votes')
plt.title('Average Votes by Decade and Duration Category')

# Plot line chart of votes
data_india.groupby('Decade')['Votes'].mean().plot(ax=ax, kind='line', color='red', marker='o', label='Average Votes')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the chart
plt.show()

# %%
india_bar_data = all_tables.groupby(['Genre','Category'])['Rating'].mean().unstack()
india_bar_data
# Out:
# Category      long    medium     short
# Genre
# Action    5.086228  4.966667  4.500000
# Drama     6.404376  6.582759  6.166667
# Horror    4.622222  4.927273  4.500000
# Musical   5.122222       NaN       NaN
# Romance   5.523770  5.700000  6.300000

# %%
ax = india_bar_data.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Duration Category')

plt.legend(bbox_to_anchor=(1.05, 1), loc='center left', borderaxespad=0.)

plt.gca().get_legend().remove()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-dfaa2bb063e5> in <cell line: 3>()
#       1 ax = india_bar_data.plot(kind='bar', figsize=(10, 6))
#       2
# ----> 3 plt.xlabel('Genre')
#       4 plt.ylabel('Rating')
#       5 plt.title('Rating by Genre and Duration Category')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## HW วาด Stacked หรือ Grouped Bar Chart ของข้อมูลหนัง india แล้วนำมา Present วันพุธที่ 11 กันยายน 2567

# %%
data_india
# Out:
#       Year  Duration  Votes
# 1                109      8
# 3                110     35
# 5                147    827
# 6                142  1,086
# 8                 82    326
# ...    ...       ...    ...
# 15493            115    408
# 15494            153  1,496
# 15503            125     44
# 15505            129    655
# 15508            130     20
#
# [5851 rows x 3 columns]

# %%
data_india_hw = data_india.dropna(subset=['Year','Genre','Rating'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-b643b37b9720> in <cell line: 1>()
# ----> 1 data_india_hw = data_india.dropna(subset=['Year','Genre','Rating'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6416             check = indices == -1
#    6417             if check.any():
# -> 6418                 raise KeyError(np.array(subset)[check].tolist())
#    6419             agg_obj = self.take(indices, axis=agg_axis)
#    6420
#
# KeyError: ['Genre', 'Rating']

# %%
data_india_hw = data_india_hw[['Year','Genre','Rating']] # Use square brackets to select columns
data_india_hw
# Out:
#          Year                      Genre  Rating
# 1      (2019)                      Drama     7.0
# 3      (2019)            Comedy, Romance     4.4
# 5      (1997)     Comedy, Drama, Musical     4.7
# 6      (2005)        Drama, Romance, War     7.4
# 8      (2012)  Horror, Mystery, Thriller     5.6
# ...       ...                        ...     ...
# 15501  (1992)       Action, Crime, Drama     5.3
# 15503  (1989)       Action, Crime, Drama     5.8
# 15504  (1988)                     Action     4.6
# 15505  (1999)              Action, Drama     4.5
# 15508  (1998)              Action, Drama     6.2
#
# [7817 rows x 3 columns]

# %%
data_india_hw['Year'] = data_india_hw['Year'].str.replace('(', ' ')
data_india_hw['Year'] = data_india_hw['Year'].str.replace(')', ' ')
data_india_hw['Year']
# Out:
# 1         2019
# 3         2019
# 5         1997
# 6         2005
# 8         2012
#           ...
# 15501     1992
# 15503     1989
# 15504     1988
# 15505     1999
# 15508     1998
# Name: Year, Length: 7817, dtype: object

# %%
data_india_hw['Year'] = data_india_hw['Year'].astype(int)

# %%
# prompt: แยกตารางออกเป็นตารางย่อย 5 ตารางสำหรับ genre: Drama,Action,Romance,Horror,Musical

# Create a dictionary to store the dataframes for each genre
genre_dfs = {}

# Define the genres to extract
genres = ['Drama', 'Action', 'Romance', 'Horror', 'Musical']

# Iterate over the genres and create separate dataframes
for genre in genres:
  genre_dfs[genre] = data_india_hw[data_india_hw['Genre'] == genre].copy()

# Access the dataframes using the genre as the key
# Example:
# drama_df = genre_dfs['Drama']
# action_df = genre_dfs['Action']
# ...

# %%
all_tables_hw = pd.concat(genre_dfs.values())
all_tables_hw.head()
# Out:
#     Year  Genre  Rating
# 1   2019  Drama     7.0
# 10  2004  Drama     6.2
# 30  2005  Drama     7.1
# 32  1993  Drama     5.6
# 36  2004  Drama     4.5

# %%
# prompt: สร้างแบ่งช่วงปี โดยเว้นช่วงซัก 20 ปี

# Create a function to categorize years
def categorize_year(year):
  if year < 1960:
    return 'Before 1960'
  elif 1960 <= year < 1980:
    return '1960s - 1970s'
  elif 1980 <= year < 2000:
    return '1980s - 1990s'
  elif 2000 <= year < 2020:
    return '2000s - 2010s'
  else:
    return '2020s and later'

# Apply the function to the 'Year' column
all_tables_hw['Year Category'] = all_tables_hw['Year'].apply(categorize_year)

# %%
india_bar_data_hw = all_tables_hw.groupby(['Genre','Year Category'])['Rating'].mean().unstack()
india_bar_data_hw
# Out:
# Year Category  1960s - 1970s  1980s - 1990s  2000s - 2010s  2020s and later  \
# Genre
# Biography                NaN       5.400000       5.900000         4.200000
# Documentary         7.025000       7.690000       7.662121         8.250000
# Family              6.477778       5.166667       6.720000         7.466667
# History             7.050000       5.400000       6.450000              NaN
#
# Year Category  Before 1960
# Genre
# Biography              7.1
# Documentary            NaN
# Family                 NaN
# History                6.0

# %%
ax = india_bar_data_hw.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Year Category')

plt.legend(bbox_to_anchor=(1.05, 1), loc='center left', borderaxespad=0.)

plt.gca().get_legend().remove()

plt.show()

# %%
ax = india_bar_data_hw.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Year Category')

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1.05, 0.5))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-48fc9165948a> in <cell line: 3>()
#       1 ax = india_bar_data_hw.plot(kind='bar', figsize=(10, 6))
#       2
# ----> 3 plt.xlabel('Genre')
#       4 plt.ylabel('Rating')
#       5 plt.title('Rating by Genre and Year Category')
#
# NameError: name 'plt' is not defined

# %%
ax = india_bar_data_hw.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Year Category')

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1.05, 0.5), title='Year Category')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
ax = india_bar_data_hw.plot(kind='bar', figsize=(25, 12))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Year Category')

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1.05, 0.5), title='Year Category')

# แก้ไขตำแหน่งของการแสดงค่าให้อยู่ภายในแท่งกราฟ
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # ข้อความแสดงค่า
                (p.get_x() + p.get_width() / 2., p.get_height() / 2.),  # แสดงข้อความที่กึ่งกลางแท่ง
                ha='center', va='center', color='white', fontsize=10)  # จัดตำแหน่งให้อยู่กลางแท่งและใช้สีขาวเพื่อให้ชัดเจน

plt.show()

# %%
ax = india_bar_data_hw.plot(kind='bar', figsize=(20, 10))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Year Category')

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1.05, 0.5), title='Year Category')

# แก้ไขตำแหน่งของการแสดงค่าให้อยู่ภายในแท่งกราฟและหมุนตัวเลขให้อยู่แนวนอน
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # ข้อความแสดงค่า
                (p.get_x() + p.get_width() / 2., p.get_height() / 2.),  # แสดงข้อความที่กึ่งกลางแท่ง
                ha='center', va='center', color='white', fontsize=10, rotation=90)  # เพิ่ม rotation=0 เพื่อให้ตัวเลขอยู่ในแนวนอน

plt.show()

# %%
path = '/content/drive/My Drive/Data_viz_2024/Movies.csv'

# %%
data_india = pd.read_csv(path, encoding='latin-1') # Try reading the file with 'latin-1' encoding
data_india.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-1cf773058cbe> in <cell line: 1>()
# ----> 1 data_india = pd.read_csv(path, encoding='latin-1') # Try reading the file with 'latin-1' encoding
#       2 data_india.head()
#
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # เอาโค้ดนี้ๆๆๆๆๆ♥

# %%
data_india_hw = data_india.dropna(subset=['Year','Genre','Rating'])

# %%
data_india_hw = data_india_hw[['Year','Genre','Rating']] # Use square brackets to select columns
data_india_hw
# Out:
#          Year                      Genre  Rating
# 1      (2019)                      Drama     7.0
# 3      (2019)            Comedy, Romance     4.4
# 5      (1997)     Comedy, Drama, Musical     4.7
# 6      (2005)        Drama, Romance, War     7.4
# 8      (2012)  Horror, Mystery, Thriller     5.6
# ...       ...                        ...     ...
# 15501  (1992)       Action, Crime, Drama     5.3
# 15503  (1989)       Action, Crime, Drama     5.8
# 15504  (1988)                     Action     4.6
# 15505  (1999)              Action, Drama     4.5
# 15508  (1998)              Action, Drama     6.2
#
# [7817 rows x 3 columns]

# %%
data_india_hw['Year'] = data_india_hw['Year'].str.replace('(', ' ')
data_india_hw['Year'] = data_india_hw['Year'].str.replace(')', ' ')
data_india_hw['Year']
# Out:
# 1         2019
# 3         2019
# 5         1997
# 6         2005
# 8         2012
#           ...
# 15501     1992
# 15503     1989
# 15504     1988
# 15505     1999
# 15508     1998
# Name: Year, Length: 7817, dtype: object

# %%
data_india_hw['Year'] = data_india_hw['Year'].astype(int)

# %%
top_20_genres = data_india_hw.groupby('Genre')['Rating'].mean().sort_values(ascending=False).head(20)
top_20_genres
# Out:
# Genre
# History, Romance                   9.40
# Documentary, Family, History       9.30
# Documentary, Music                 8.90
# Documentary, Biography, Music      8.80
# Documentary, Sport                 8.60
# Animation, Comedy, Family          8.30
# Biography, Family                  8.30
# Documentary, Thriller              8.25
# Documentary, Biography, Family     8.25
# Documentary, Biography, Sport      8.20
# Documentary, Drama, Sport          8.10
# Drama, Musical, Sport              8.10
# Documentary, Biography, Musical    8.05
# Crime, Drama, History              8.05
# Documentary, History, News         8.00
# Comedy, Musical, Drama             8.00
# Documentary, War                   8.00
# Fantasy, Musical, Mystery          8.00
# Drama, Crime, Mystery              7.90
# Drama, Fantasy, History            7.90
# Name: Rating, dtype: float64

# %%
# Create a dictionary to store the dataframes for each genre
genre_dfs = {}

# Define the genres to extract
genres = ['History', 'Documentary', 'Biography', 'Family', 'Fantasy']

# Iterate over the genres and create separate dataframes
for genre in genres:
  genre_dfs[genre] = data_india_hw[data_india_hw['Genre'] == genre].copy()

# %%
all_tables_hw = pd.concat(genre_dfs.values())
all_tables_hw.head()
# Out:
#       Year    Genre  Rating
# 1142  2006  History     6.6
# 1273  1981  History     4.6
# 2473  2010  History     8.2
# 2871  2016  History     6.6
# 3966  2002  History     4.2

# %%
def categorize_year(year):
  if year < 1960:
    return 'Before 1960'
  elif 1960 <= year < 1980:
    return '1960s - 1980s'
  elif 1980 <= year < 2000:
    return '1980s - 2000s'
  elif 2000 <= year < 2020:
    return '2000s - 2020s'
  else:
    return '2020s and later'

all_tables_hw['Year Category'] = all_tables_hw['Year'].apply(categorize_year)

# %%
all_tables_hw
# Out:
#        Year    Genre  Rating  Year Category
# 1142   2006  History     6.6  2000s - 2020s
# 1273   1981  History     4.6  1980s - 2000s
# 2473   2010  History     8.2  2000s - 2020s
# 2871   2016  History     6.6  2000s - 2020s
# 3966   2002  History     4.2  2000s - 2020s
# ...     ...      ...     ...            ...
# 12543  1964  Fantasy     6.9  1960s - 1980s
# 13044  1982  Fantasy     6.4  1980s - 2000s
# 13462  1961  Fantasy     7.5  1960s - 1980s
# 14547  2005  Fantasy     4.6  2000s - 2020s
# 14886  1986  Fantasy     6.8  1980s - 2000s
#
# [200 rows x 4 columns]

# %%
india_bar_data_hw = all_tables_hw.groupby(['Genre','Year Category'])['Rating'].mean().unstack()
india_bar_data_hw
# Out:
# Year Category  1960s - 1980s  1980s - 2000s  2000s - 2020s  2020s and later  \
# Genre
# Biography                NaN       5.400000       5.900000         4.200000
# Documentary         7.025000       7.690000       7.662121         8.250000
# Family              6.477778       5.166667       6.720000         7.466667
# Fantasy             6.700000       6.654545       4.744444              NaN
# History             7.050000       5.400000       6.450000              NaN
#
# Year Category  Before 1960
# Genre
# Biography         7.100000
# Documentary            NaN
# Family                 NaN
# Fantasy           7.071429
# History           6.000000

# %%
# Reorder the columns in india_bar_data_hw
new_order = ['Before 1960', '1960s - 1980s', '1980s - 2000s', '2000s - 2020s', '2020s and later']
india_bar_data_hw = india_bar_data_hw[new_order]

ax = india_bar_data_hw.plot(kind='bar', figsize=(20, 10))

plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Rating by Genre and Year Category')

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1.05, 0.5), title='Year Category')

# แก้ไขตำแหน่งของการแสดงค่าให้อยู่ภายในแท่งกราฟและหมุนตัวเลขให้อยู่แนวนอน
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # ข้อความแสดงค่า
                (p.get_x() + p.get_width() / 2., p.get_height() / 2.),  # แสดงข้อความที่กึ่งกลางแท่ง
                ha='center', va='center', color='white', fontsize=10, rotation=90)  # เพิ่ม rotation=0 เพื่อให้ตัวเลขอยู่ในแนวนอน

plt.show()

# %% [markdown]
# ***โน๊ตพรี***
#
# Biography(ชีวประวัติ)
#
# 1.เป็นประเภทหนังที่เริ่มผลิตก่อนปี1960และได้รับความนิยมมากเนื่องจากมีการสร้างหนังเกี่ยวกับชีวประวัติของนักต่อสู้เพื่อเอกราชหรือผู้นำทางการเมือง ซึ่งได้รับความนิยมได้ช่วงนั้นมากทำให้เรทติ้งสูงเป็นพิเศษ
#
# 2.แต่เมื่อในปี1960-1970 ที่ทำให้ไม่มีการทำหนังแนวนี้เพราะในช่วงปีนี้ความนิยมในการทำหนังที่เน้นความบันเทิง มากกว่าชีวประวัติหรือหนังจริงๆจัง เพราะเป็นช่วงบูมของBollywood India
#
# 3.ในช่วงปี1980-1990 เป็นการกลับมาทำหนังชีวประวัติอีกครั้งแต่เรทติ้งยังน้อยเนื่องจากไม่สามารถดึงดูดผู้คนได้มาก
#
# 4.ในช่วงปี2000-2010 เป็นช่วงที่เทคโนยีมีการพัฒนามากขึ้น ทำให้มีค่าเฉลี่ยที่ดีขึ้นจากปีก่อนๆ
#
# 5.และตั้งแต่ในปี2020 ความนิยมของหนังประเภทชีวประวัติก็ไม่ตอบโจทย์สำหรับคนยุคสมัยใหม่ที่นิยมหนังที่มีความบรรเทิง
#
# Documentary(สารคดี) = เป็นประเภทหนังที่ได้รับความนิยมมากและมีแนวโน้มRatingในแต่ละปีสูงขึ้นเรื่อยๆ เนื่องจากก่อนปี1960 มีข้อจำกัดในเรื่องของเทคโนโลยีการถ่ายทำจึงทำให้ยังไม่มีการผลิตหนังแนวนี้ออกมา
#
# Family(ครอบครัว) = ประเภทหนังแนวครอบครัวถูกผลิตออกมามากในแต่ละปีและมีการควบคู่ไปกับหนังหลายประเภทไม่ว่าจะเป็น comedy, drama, romance
#
# Fantasy(แฟนตาซี) =
# History(ประวัติศาสตร์)  = ค่าแนวโน้มแต่ละปีมีการขึ้นลงไม่ต่อเนื่อง เนื่องจากหนังประเภทนี้มีการจัดทำในเรื่องความสนใจในประวัติศาสตร์ไม่เหมือนกันในแต่ละปี ความนิยมที่เปลี่ยนไปทำให้

# %% [markdown]
# ## Study

# %% [markdown]
# แสดงปริมาณคนเข้าเว๊ปในแต่ละวัน โดยเปรียบเทียบช่วงเวลา 11:00-12:00 กับ 23:00-24:00
#
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)
& (data['search_timestamp'].dt.time < time(hour=12))
& (data['search_timestamp'].dt.time >= time(hour=11))].shape[0]  # monday 11:00-12:00
# Out:
# 73249

# %%
b4lunch = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0]
                         ]

# %%
b4lunch
# Out:
# [73249, 73083, 75429, 78024, 99007, 174165, 165440]

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
# Out:
# 31874

# %%
b4midnight = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
                         ]
b4midnight
# Out:
# [31874, 32258, 31153, 35944, 53174, 58306, 35801]

# %%
labels = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
import numpy as np

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, b4lunch, width, label='lunch time',color = '#fc9700')
rects2 = ax.bar(x + width/2, b4midnight, width, label='midnight',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน เปรียบเทียบ 2 ช่วงเวลา')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

# %% [markdown]
# ## Stacked bar chart

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %%
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.barh(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.barh(labels, b4midnight, width, left=b4lunch, label='before midnight',color = '#19038a')

ax.set_xlabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %% [markdown]
# ## [เช็คชื่อ] โดยให้วาด Bar chart ที่เปรียบเทียบปริมาณคนใช้งาน Wongnai.com สองช่วงเวลา โดยให้กราฟแสดงสัดส่วนของปริมาณคนใช้งานในแต่ละวันด้วย

# %% [markdown]
# ## Histogram

# %% [markdown]
# ## กราฟแสดงความถี่ของข้อมูล

# %% [markdown]
# ตัวอย่างข้อมูลที่ random มาจาก normal distribution ที่มี mean = 100  และ stdev = 15

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(2024)

mu, sigma = 100, 15
X = mu + sigma * np.random.randn(10000)

plt.hist(X, 50, density = True, facecolor = 'violet', alpha = 0.75)
# Out:
# (array([8.25589208e-05, 8.25589208e-05, 8.25589208e-05, 1.65117842e-04,
#         3.71515144e-04, 5.77912446e-04, 7.01750827e-04, 1.60989896e-03,
#         1.94013464e-03, 2.43548816e-03, 3.71515144e-03, 5.94424230e-03,
#         6.56343421e-03, 8.33845100e-03, 1.18884846e-02, 1.34158246e-02,
#         1.60164306e-02, 1.77501680e-02, 2.09286864e-02, 2.21670702e-02,
#         2.49327941e-02, 2.65014136e-02, 2.68316493e-02, 2.53868682e-02,
#         2.43548816e-02, 2.25385854e-02, 2.20432319e-02, 2.09286864e-02,
#         1.77088885e-02, 1.47367674e-02, 1.33332657e-02, 9.61811428e-03,
#         8.09077424e-03, 7.05878773e-03, 4.66457903e-03, 3.01340061e-03,
#         2.10525248e-03, 1.48606057e-03, 1.07326597e-03, 9.08148129e-04,
#         2.06397302e-04, 1.23838381e-04, 8.25589208e-05, 8.25589208e-05,
#         8.25589208e-05, 0.00000000e+00, 8.25589208e-05, 0.00000000e+00,
#         0.00000000e+00, 4.12794604e-05]),
#  array([ 44.90650513,  47.32901741,  49.7515297 ,  52.17404198,
# ...

# %% [markdown]
# ## India Movies test

# %%
data_india = pd.read_csv(india_file_path, encoding='latin-1') # Try reading the file with 'latin-1' encoding
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data_india = data_india.dropna(subset=['Genre'])

# %%
len(set(data_india.dropna(subset=['Genre'])['Genre']))
# Out:
# 485

# %%
# prompt: spit value  in column Genre by ',' and make more  column for of those

# Assuming 'movie_file_path' is your DataFrame and contains a 'Genre' column
# Create a new DataFrame to store the expanded genres
expanded_genres = data_india['Genre'].str.split(',', expand=True)

# Rename the new columns with meaningful names
expanded_genres.columns = ['Genre1', 'Genre2', 'Genre3']

# Concatenate the expanded genres with the original DataFrame
data_india = pd.concat([data_india, expanded_genres], axis=1)

# Display the updated DataFrame
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3  Genre1    Genre2 Genre3
# 0  Rajendra Bhatia   Drama      None   None
# ...

# %%
# prompt: delete space in the value in Genre 1 Genre2 Genre3

# Delete spaces in the 'Genre1', 'Genre2', and 'Genre3' columns
data_india['Genre1'] = data_india['Genre1'].str.replace(' ', '')
data_india['Genre2'] = data_india['Genre2'].str.replace(' ', '')
data_india['Genre3'] = data_india['Genre3'].str.replace(' ', '')

# %%
all_genres = pd.concat([data_india['Genre1'], data_india['Genre2'], data_india['Genre3']])

# %%
all_genres[:13]
# Out:
# ['Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Horror',
#  'Action',
#  'Drama',
#  'Horror',
#  'Horror']

# %%
len(set(all_genres))
# Out:
# 25

# %%
# Replace None values with 'Unknown'
all_genres = [x for x in all_genres if x is not None]

plt.hist(all_genres, bins = len(set(all_genres)))
plt.xticks(rotation='vertical');

# %% [markdown]
# ## quiz 15 นับ set พระเอก นางเอกที่เล่นคู่กัน Actor1 Actor2

# %%
# prompt: merge column Actor 1 Actor 2

# Assuming your DataFrame is named 'data_india'
data_india['Actor_Pair'] = data_india['Actor 1'] + ' & ' + data_india['Actor 2']
# Out:
#             Actor 1          Actor 2  Count
# 3695      Jeetendra            Rekha     21
# 2479     Dharmendra      Hema Malini     16
# 3676      Jeetendra       Jaya Prada     15
# 2243     Dara Singh           Mumtaz     11
# 1378    Ashok Kumar   Nalini Jaywant     10
# 6834  Rajesh Khanna  Sharmila Tagore     10
# 3694      Jeetendra        Reena Roy     10
# 3673      Jeetendra      Hema Malini     10
# 5593         Nargis       Raj Kapoor      9
# 6802  Rajesh Khanna      Hema Malini      9

# %%
# prompt: นับ set พระเอก นางเอกที่เล่นคู่กัน Actor1 Actor2 เรียงลำดับด้วย

# Assuming 'data_india' is your DataFrame and contains 'Actor 1' and 'Actor 2' columns
actor_pairs = data_india.groupby(['Actor 1', 'Actor 2']).size().reset_index(name='Count').sort_values(by='Count', ascending=False)
actor_pairs['Actor_Pair'] = actor_pairs['Actor 1'] + ' & ' + actor_pairs['Actor 2']
# Display the result
actor_pairs
# Out:
#                  Actor 1                 Actor 2  Count  \
# 3695           Jeetendra                   Rekha     21
# 2479          Dharmendra             Hema Malini     16
# 3676           Jeetendra              Jaya Prada     15
# 2243          Dara Singh                  Mumtaz     11
# 1378         Ashok Kumar          Nalini Jaywant     10
# ...                  ...                     ...    ...
# 3600       Jaya Bachchan  Sabyasachi Chakrabarty      1
# 3601   Jaya Bhattacharya      Master Ashish Gaur      1
# 3602   Jaya Bhattacharya           Rashmi Gulati      1
# 3603       Jaya Kausalya             Jaya Kumari      1
# 10289        Zulfi Sayed             Sonya Jehan      1
#
#                                    Actor_Pair
# 3695                        Jeetendra & Rekha
# 2479                 Dharmendra & Hema Malini
# 3676                   Jeetendra & Jaya Prada
# 2243                      Dara Singh & Mumtaz
# 1378             Ashok Kumar & Nalini Jaywant
# ...

# %%
len(set(actor_pairs['Actor_Pair']))
# Out:
# 54

# %%
# prompt: จากนั้นทำข้อมูล actor_pairs มาสร้าง Histogram ด้วยแกน x คือชื่่อพระเอกนางเอกที่เล่นด้วยกัน แกน y เป็นจำนวนเรื่องที่พระนางเล่นด้วยกัน

import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))  # Adjust figure size as needed

# Reset the index to make 'Actor 1' and 'Actor 2' columns accessible again
actor_pairs = actor_pairs.reset_index()

# Convert the actor pairs to strings for x-axis labels
x_labels = [', '.join(str(i) for i in pair) for pair in zip(actor_pairs['Actor 1'], actor_pairs['Actor 2'])]

plt.bar(x_labels, actor_pairs['Count'].values)
plt.xlabel('Actor Pairs (Actor 1, Actor 2)')
plt.ylabel('Number of Movies Together')
plt.title('Frequency of Actor Pairs in Movies')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ตัวอย่างข้อมูล wongnai.com

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[15,15]
output = plt.hist(list(data['number_of_result']),10,facecolor = 'red' ,alpha = 0.75)

# %% [markdown]
# แก้ไข แกน x ที่เรียงข้อมูลผิด

# %%
data.dtypes
# Out:
# Unnamed: 0                   int64
# search_id                   object
# search_timestamp    datetime64[ns]
# user_agent                  object
# q                           object
# user_id                    float64
# session_id                  object
# number_of_result            object
# lat                         object
# long                        object
# dtype: object

# %% [markdown]
# เรียกดู data type ของ ตัวแปร

# %%
type(data['number_of_result'][0])
# Out:
# int

# %% [markdown]
# ตรวจสอบ data type ของตัวแปร

# %%
type(data['number_of_result'][0]) == int
# Out:
# True

# %% [markdown]
# ตรวจสอบดูทุกๆค่าใน column 'number_of_result'

# %%
# for x in data['number_of_result']:
#     if type(x) != int:
#         print(f'{x} -> {type(x)}')

# %%
new_type = data['number_of_result'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-29dba17f7bb1> in <module>()
# ----> 1 new_type = data['number_of_result'].astype('int32')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %% [markdown]
# ลบ record ที่มีค่า ใน column 'number_of_result' เป็น number of result

# %%
data[data['number_of_result']=='number_of_result']
# Out:
#          Unnamed: 0  search_id search_timestamp  ...  number_of_result  lat  long
# 1000016     1000032  search_id              NaT  ...  number_of_result  lat  long
#
# [1 rows x 10 columns]

# %%
data = data.drop(1000016)

# %%
data[data['number_of_result']=='number_of_result']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, search_id, search_timestamp, user_agent, q, user_id, session_id, number_of_result, lat, long]
# Index: []

# %%
new_type = data['number_of_result'].astype('int32')

# %%
output = plt.hist(new_type,100,facecolor = 'red' ,alpha = 0.75)

# %% [markdown]
# ลบ outlier

# %%
new_type_nooutlier = new_type[new_type < 25]

# %%
new_type.shape[0] - new_type_nooutlier.shape[0]
# Out:
# 14

# %%
matplotlib.rcParams['figure.figsize']=[8,8]
output = plt.hist(new_type_nooutlier,10,facecolor = 'red' ,alpha = 0.75)

# %% [markdown]
# Quiz 7 เปรียบเทียบความถี่ของแท่งที่มีค่ามากที่สุด กับ แท่งอื่นๆรวมกัน

# %%
output
# Out:
# (array([ 670293., 1247269., 1921441.,   51703.,   50609.,  167502.,
#           36883.,   35914.,  105490., 5717238.]),
#  array([ 0. ,  2.2,  4.4,  6.6,  8.8, 11. , 13.2, 15.4, 17.6, 19.8, 22. ]),
#  <a list of 10 Patch objects>)

# %%
output[0]
# Out:
# array([ 670293., 1247269., 1921441.,   51703.,   50609.,  167502.,
#          36883.,   35914.,  105490., 5717238.])

# %%
output[0][-1]
# Out:
# 5717238.0

# %%
sum(output[0][:-1])
# Out:
# 4287104.0

# %% [markdown]
# ## Tree map

# %%
# !pip install squarify

# %%
import numpy as np
import matplotlib.pyplot as plt
import squarify

# %%
squarify.plot(output[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-b8ff17ad66d1> in <cell line: 1>()
# ----> 1 squarify.plot(all_genres['0'])
#
# TypeError: list indices must be integers or slices, not str

# %%
# prompt: plot treemap for all_genres use squarify

import matplotlib.pyplot as plt
import squarify

# Assuming 'all_genres' is a list or Series containing the genres
genre_counts = all_genres.value_counts()

# Plot the treemap
plt.figure(figsize=(10, 6))
squarify.plot(sizes=genre_counts.values, label=genre_counts.index, alpha=.8)
plt.axis('off')
plt.show()

# %%
squarify.plot(output[0],value=output[0])

# %%
squarify.plot(output[0],value=output[0],norm_y=60)

# %% [markdown]
# ## Radar Chart

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data = {'client_id' : ['c1' , 'c2' , 'c3' , 'c4'],
         'cheese' : [2,5,4,3],
         'beer' : [2,1,3,5],
         'chicken' : [5,3,3,4],
        'bread' : [4,3,2,1],
       'coffee' : [2,3,5,3]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df.columns[1:])
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid' , color = '#ea3033') #เส้นกราฟ
ax.fill(angles, values, 'lightpink', alpha=0.5) #พื้นที่

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %% [markdown]
# ## HW9 Radar Chart for analyze genre of movies by rating, voting, duration, Year, Director

# %%
data_india
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...
